# %%
x = 1453
a = 0

while x > 0 :
    resto = x % 10
    x = x // 10
    a = a + resto
print(a)
# Out:
# 13

# %%
num = 14503
s = 0 
while True:
    resto = num % 10
    num = num // 10
    s = s + resto
    
    if num < 1: # 145 
        break
print(s)
# Out:
# 13

# %%
1 % 10
# Out:
# 1

# %%
r = 0
x = 145
a = 0
resto = 0

while (r > 9):
    resto = x % 10
    a = a + resto
    x = x // 10
    print(a)
